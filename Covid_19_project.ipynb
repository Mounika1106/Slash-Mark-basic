# %% [markdown]
# <a href="https://colab.research.google.com/github/Mounika1106/Slash-Mark-basic/blob/main/Covid_19_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data = pd.read_csv(r"countrywise.csv")

# %%
data.head()
# Out:
#        Country  Confirmed  Deaths  Recovered  Active  New Cases  \
# 0  Afghanistan     209436    7896          0  201540         30
# 1      Albania     334427    3598          0  330829          0
# 2      Algeria     271490    6881          0  264609         13
# 3      Andorra      47875     165          0   47710          0
# 4       Angola     105277    1933          0  103344          0
#
#    Deaths / 100 Cases  Recovered / 100 Cases  Deaths / 100 Recovered  \
# 0                3.77                    0.0                     0.0
# 1                1.08                    0.0                     0.0
# 2                2.53                    0.0                     0.0
# 3                0.34                    0.0                     0.0
# 4                1.84                    0.0                     0.0
#
#    Population  Cases / Million People  Confirmed last week  1 week change  \
# 0    38928341                  5380.0               209322            114
# ...

# %%
data
# Out:
#                   Country  Confirmed  Deaths  Recovered  Active  New Cases  \
# 0             Afghanistan     209436    7896          0  201540         30
# 1                 Albania     334427    3598          0  330829          0
# 2                 Algeria     271490    6881          0  264609         13
# 3                 Andorra      47875     165          0   47710          0
# 4                  Angola     105277    1933          0  103344          0
# ..                    ...        ...     ...        ...     ...        ...
# 196    West Bank and Gaza     703228    5708          0  697520          0
# 197  Winter Olympics 2022        535       0          0     535          0
# 198                 Yemen      11945    2159          0    9786          0
# 199                Zambia     343135    4057          0  339078          0
# 200              Zimbabwe     264127    5668          0  258459          0
#
# ...

# %%
data.columns
# Out:
# Index(['Country', 'Confirmed', 'Deaths', 'Recovered', 'Active', 'New Cases',
#        'Deaths / 100 Cases', 'Recovered / 100 Cases', 'Deaths / 100 Recovered',
#        'Population', 'Cases / Million People', 'Confirmed last week',
#        '1 week change', '1 week % increase'],
#       dtype='object')

# %%
data.tail()
# Out:
#                   Country  Confirmed  Deaths  Recovered  Active  New Cases  \
# 196    West Bank and Gaza     703228    5708          0  697520          0
# 197  Winter Olympics 2022        535       0          0     535          0
# 198                 Yemen      11945    2159          0    9786          0
# 199                Zambia     343135    4057          0  339078          0
# 200              Zimbabwe     264127    5668          0  258459          0
#
#      Deaths / 100 Cases  Recovered / 100 Cases  Deaths / 100 Recovered  \
# 196                0.81                    0.0                     0.0
# 197                0.00                    0.0                     0.0
# 198               18.07                    0.0                     0.0
# 199                1.18                    0.0                     0.0
# 200                2.15                    0.0                     0.0
#
#      Population  Cases / Million People  Confirmed last week  1 week change  \
# ...

# %%
data.describe()
# Out:
#           Confirmed        Deaths  Recovered        Active     New Cases  \
# count  2.010000e+02  2.010000e+02      201.0  2.010000e+02    201.000000
# mean   3.364246e+06  3.422407e+04        0.0  3.330022e+06    648.940299
# std    1.011501e+07  1.107561e+05        0.0  1.001807e+07   3290.232187
# min    1.000000e+00  0.000000e+00        0.0 -5.000000e+00      0.000000
# 25%    3.749100e+04  3.720000e+02        0.0  3.665800e+04      0.000000
# 50%    3.166010e+05  3.164000e+03        0.0  3.153820e+05      0.000000
# 75%    1.703850e+06  1.906900e+04        0.0  1.695159e+06     20.000000
# max    1.036909e+08  1.122516e+06        0.0  1.025684e+08  35371.000000
#
#        Deaths / 100 Cases  Recovered / 100 Cases  Deaths / 100 Recovered  \
# count          201.000000                  201.0                   201.0
# mean             4.472985                    0.0                     0.0
# std             42.272567                    0.0                     0.0
# ...

# %%
data.isnull()
# Out:
#      Country  Confirmed  Deaths  Recovered  Active  New Cases  \
# 0      False      False   False      False   False      False
# 1      False      False   False      False   False      False
# 2      False      False   False      False   False      False
# 3      False      False   False      False   False      False
# 4      False      False   False      False   False      False
# ..       ...        ...     ...        ...     ...        ...
# 196    False      False   False      False   False      False
# 197    False      False   False      False   False      False
# 198    False      False   False      False   False      False
# 199    False      False   False      False   False      False
# 200    False      False   False      False   False      False
#
#      Deaths / 100 Cases  Recovered / 100 Cases  Deaths / 100 Recovered  \
# 0                 False                  False                   False
# 1                 False                  False                   False
# ...

# %% [markdown]
# Scatterplot

# %%
data.columns
# Out:
# Index(['Country', 'Confirmed', 'Deaths', 'Recovered', 'Active', 'New Cases',
#        'Deaths / 100 Cases', 'Recovered / 100 Cases', 'Deaths / 100 Recovered',
#        'Population', 'Cases / Million People', 'Confirmed last week',
#        '1 week change', '1 week % increase'],
#       dtype='object')

# %%
sns.relplot(x="Confirmed",y="Confirmed last week",data=data)

# %%
sns.pairplot(data)

# %%
sns.relplot(x="Confirmed",y="Confirmed last week",kind="line",data=data)

# %%
sns.boxplot(x="Confirmed",y="Confirmed last week",data=data)
# Out:
# <Axes: xlabel='Confirmed', ylabel='Confirmed last week'>

# %%
sns.lineplot(x="Confirmed",y="Confirmed last week",data=data)
# Out:
# <Axes: xlabel='Confirmed', ylabel='Confirmed last week'>

# %%
sns.scatterplot(x="Confirmed",y="Confirmed last week",data=data)
# Out:
# <Axes: xlabel='Confirmed', ylabel='Confirmed last week'>

# %%
sns.histplot(x="Confirmed",y="Confirmed last week",data=data)
# Out:
# <Axes: xlabel='Confirmed', ylabel='Confirmed last week'>

# %%
sns.histplot(data['Confirmed'])
# Out:
# <Axes: xlabel='Confirmed', ylabel='Count'>

# %%
sns.violinplot(x="1 week change",y="1 week % increase",data=data)
# Out:
# <Axes: xlabel='1 week change', ylabel='1 week % increase'>
